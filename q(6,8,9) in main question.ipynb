# %% [markdown]
# ###   q 6

# %%
import random

x = random.randint(1, 200)
print(x)
# Out:
# 55

# %% [markdown]
# ### q 8

# %%
_list=[1,2,3,4,5,6,7,8]

_list= _list[::-1]
print(_list)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# ### q9

# %%
numbers=[2, 7, 3, 9, 5]
print(max(numbers))
# Out:
# 9
